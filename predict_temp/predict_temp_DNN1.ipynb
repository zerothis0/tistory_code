# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(-10, 10, 100)
y = np.maximum(0, x)  

plt.figure(figsize=(6, 4))
plt.plot(x, y, label="ReLU(x)", color='b', linewidth=2)
plt.axhline(0, color='black', linewidth=0.5)  # x축
plt.axvline(0, color='black', linewidth=0.5)  # y축
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.title("ReLU Activation Function")
plt.xlabel("x")
plt.ylabel("ReLU(x)")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-2 * np.pi, 2 * np.pi, 100)
y = np.sin(x)  

plt.figure(figsize=(6, 4))
plt.plot(x, y, label="sin(x)", color='r', linewidth=2)
plt.axhline(0, color='black', linewidth=0.5)  # x축
plt.axvline(0, color='black', linewidth=0.5)  # y축
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.title("Sine Function")
plt.xlabel("x")
plt.ylabel("sin(x)")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


x = np.linspace(-10, 10, 100)
y = x**2 
y1 = x

plt.figure(figsize=(6, 4))
plt.plot(x, y, label="y=x^2", color='k', linewidth=2)
plt.axhline(0, color='black', linewidth=0.5)  # x축
plt.axvline(0, color='black', linewidth=0.5)  # y축
plt.grid(True, linestyle='--', alpha=0.6)
plt.legend()
plt.xlabel("x")
plt.ylabel('y')
plt.show()
